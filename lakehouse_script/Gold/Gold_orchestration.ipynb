# %% [markdown]
# #Orchestration Logic
#
# this notebook programmatically runs all the gold notebook in the sequence.
# it becomes single entry point for thr gold layer in databricks jobs

# %%
notebooks = [
    "./Gold_dim_customers",
    "./Gold_dim_products",
    "./Gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
